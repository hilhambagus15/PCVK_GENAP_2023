# %% [markdown]
# <a href="https://colab.research.google.com/github/hilhambagus15/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/YEJI.jpg')
plt.imshow(img)

# %%
img = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)   #konversi channel BGR  ->  RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Pengolahan Citra/YEJI.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10)) # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # TUGAS

# %%
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
plt.imshow(img[5:30])

# %% [markdown]
# imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
# fig = plt.figure(figsize=(10,10))
# cv.rectangle(imageWithRectangle, pt1=(500,800), pt2=(100,95), color=(0,255, 255), thickness = 20)
# cv.rectangle(imageWithRectangle, pt1=(450,700), pt2=(150,200), color=(0,255,0), thickness = 40)
# cv.rectangle(imageWithRectangle, pt1=(650,200), pt2=(50,600), color=(255,255,255), thickness = 20)
# cv.rectangle(imageWithRectangle, pt1=(550,150), pt2=(80,900), color=(255,0,0), thickness = 25)
# cv.rectangle(imageWithRectangle, pt1=(500,150), pt2=(30,750), color=(0,0,255),thickness=17)
# plt.imshow(imageWithRectangle)

# %%
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
cv.rectangle(imageWithRectangle, pt1=(500,800), pt2=(100,95), color=(0,255, 255), thickness = 20)
cv.rectangle(imageWithRectangle, pt1=(450,700), pt2=(150,200), color=(0,255,0), thickness = 40)
cv.rectangle(imageWithRectangle, pt1=(650,200), pt2=(50,600), color=(255,255,255), thickness = 20)
cv.rectangle(imageWithRectangle, pt1=(550,150), pt2=(80,900), color=(255,0,0), thickness = 25)
cv.rectangle(imageWithRectangle, pt1=(500,150), pt2=(30,750), color=(0,0,255),thickness=17)
plt.imshow(imageWithRectangle)

# %%
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/YEJI.jpg')

cv.rectangle(img,pt1=(100,200),pt2=(500,600),color=(0,255,0),thickness=5)
cv.circle(img,center=(300,400),radius=150,color=(255,0,0),thickness=5)
plt.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/Pengolahan Citra/YEJI.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

cv.rectangle(img,pt1=(10,900),pt2=(200,1200),color=(0,255,0),thickness=10)
plt.imshow(img)
